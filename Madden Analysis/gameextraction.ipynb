# %%
#now we can create a list of games with respective player ratings
#import required modules

import pandas as pd
import numpy as np
import pickle

# %%
#unload pickled data

dict2020 = pickle.load(open("2020Dict.p","rb"))
dict2021 = pickle.load(open("2021Dict.p","rb"))
dict2022 = pickle.load(open("2022Dict.p","rb"))

# %%
#import games
games2020 = pd.read_csv("2020schedtrimmed.csv")
games2020
# Out:
#                      For                Against  Differential
# 0     Kansas City Chiefs         Houston Texans            14
# 1       Seattle Seahawks        Atlanta Falcons            13
# 2          Buffalo Bills          New York Jets            10
# 3      Las Vegas Raiders      Carolina Panthers             4
# 4          Chicago Bears          Detroit Lions             4
# ..                   ...                    ...           ...
# 507       Denver Broncos      Las Vegas Raiders            -1
# 508       Houston Texans       Tennessee Titans            -3
# 509   Kansas City Chiefs   Los Angeles Chargers           -17
# 510  San Francisco 49ers       Seattle Seahawks            -3
# 511  Philadelphia Eagles  Washington Commanders            -6
#
# [512 rows x 3 columns]

# %%
#shortening each team name
games2020["For"] = games2020["For"].apply(lambda x: x.split(" ")[-1])
games2020["Against"] = games2020["Against"].apply(lambda x: x.split(" ")[-1])
games2020
# Out:
#           For     Against  Differential
# 0      Chiefs      Texans            14
# 1    Seahawks     Falcons            13
# 2       Bills        Jets            10
# 3     Raiders    Panthers             4
# 4       Bears       Lions             4
# ..        ...         ...           ...
# 507   Broncos     Raiders            -1
# 508    Texans      Titans            -3
# 509    Chiefs    Chargers           -17
# 510     49ers    Seahawks            -3
# 511    Eagles  Commanders            -6
#
# [512 rows x 3 columns]

# %%
#simplfy rows
games2020["gamename"] = games2020["For"] + " " + games2020["Against"] + " " + "2020"
games2020 = games2020.drop(columns = ["For", "Against"])
games2020
# Out:
#      Differential                gamename
# 0              14      Chiefs Texans 2020
# 1              13   Seahawks Falcons 2020
# 2              10         Bills Jets 2020
# 3               4   Raiders Panthers 2020
# 4               4        Bears Lions 2020
# ..            ...                     ...
# 507            -1    Broncos Raiders 2020
# 508            -3      Texans Titans 2020
# 509           -17    Chiefs Chargers 2020
# 510            -3     49ers Seahawks 2020
# 511            -6  Eagles Commanders 2020
#
# [512 rows x 2 columns]

# %%
#for each game, add predictors representing the strength of players from the "For" team and the "Against" team
positions = ["QB", "WR1", "WR2", "WR3", "TE", "HB", "DT", "LT", "LE", "RE", "LOLB", "MLB", "ROLB", "FS", "SS", "CB1", "CB2", "RT", "C", "LG", "RG", "K", "P"]
for pos in positions:
        games2020[pos + " " + "FOR"] = games2020["gamename"].apply(lambda x: dict2020[x.split(" ")[0]].loc[pos])
for pos in positions:
        games2020[pos + " " + "AGAINST"] = games2020["gamename"].apply(lambda x: dict2020[x.split(" ")[1]].loc[pos])
games2020 = games2020.set_index("gamename")
games2020
# Out:
#                         Differential  QB FOR  WR1 FOR  WR2 FOR  WR3 FOR  \
# gamename
# Chiefs Texans 2020                14      99       98       81       78
# Seahawks Falcons 2020             13      95       89       87       77
# Bills Jets 2020                   10      88       97       87       82
# Raiders Panthers 2020              4      83       80       79       77
# Bears Lions 2020                   4      71       90       75       75
# ...                              ...     ...      ...      ...      ...
# Broncos Raiders 2020              -1      70       82       78       78
# Texans Titans 2020                -3      90       86       85       78
# Chiefs Chargers 2020             -17      99       98       81       78
# 49ers Seahawks 2020               -3      75       81       78       77
# Eagles Commanders 2020            -6      72       80       77       76
#
#                         TE FOR  HB FOR  DT FOR  LT FOR  LE FOR  ...  \
# gamename                                                        ...
# Chiefs Texans 2020          99      84      92      75      73  ...
# Seahawks Falcons 2020       80      87      78      83      73  ...
# Bills Jets 2020             75      80      80      81      76  ...
# Raiders Panthers 2020       93      90      79      79      77  ...
# Bears Lions 2020            78      82      82      79      88  ...
# ...                        ...     ...     ...     ...     ...  ...
# Broncos Raiders 2020        82      85      70      84      82  ...
# Texans Titans 2020          76      77      69      89      95  ...
# Chiefs Chargers 2020        99      84      92      75      73  ...
# 49ers Seahawks 2020         97      86      77      94      84  ...
# Eagles Commanders 2020      84      81      94      71      85  ...
#
#                         FS AGAINST  SS AGAINST  CB1 AGAINST  CB2 AGAINST  \
# gamename
# Chiefs Texans 2020              83          72           85           78
# Seahawks Falcons 2020           77          80           78           77
# Bills Jets 2020                 75          85           82           74
# Raiders Panthers 2020           80          66           82           76
# Bears Lions 2020                80          74           80           79
# ...                            ...         ...          ...          ...
# Broncos Raiders 2020            75          74           80           79
# Texans Titans 2020              88          78           84           81
# Chiefs Chargers 2020            75          89           87           87
# 49ers Seahawks 2020             82          90           86           78
# Eagles Commanders 2020          74          79           89           80
#
#                         RT AGAINST  C AGAINST  LG AGAINST  RG AGAINST  \
# gamename
# Chiefs Texans 2020              70         70          67          68
# Seahawks Falcons 2020           71         87          68          79
# Bills Jets 2020                 69         75          73          69
# Raiders Panthers 2020           85         78          66          68
# Bears Lions 2020                74         86          71          69
# ...                            ...        ...         ...         ...
# Broncos Raiders 2020            87         92          90          80
# Texans Titans 2020              72         81          84          76
# Chiefs Chargers 2020            88         80          71          79
# 49ers Seahawks 2020             68         73          76          72
# Eagles Commanders 2020          76         77          64          87
#
#                         K AGAINST  P AGAINST
# gamename
# Chiefs Texans 2020             72         75
# Seahawks Falcons 2020          81         71
# Bills Jets 2020                67         74
# Raiders Panthers 2020          74         77
# Bears Lions 2020               80         80
# ...                           ...        ...
# Broncos Raiders 2020           73         73
# Texans Titans 2020             75         85
# Chiefs Chargers 2020           70         70
# 49ers Seahawks 2020            77         81
# Eagles Commanders 2020         74         83
#
# [512 rows x 47 columns]

# %%
#repeat for the 2021 and 2022 seasons
games2021 = pd.read_csv("2021schedtrimmed.csv")

games2022 = pd.read_csv("2022schedtrimmed.csv")

games2021["For"] = games2021["For"].apply(lambda x: x.split(" ")[-1])
games2021["Against"] = games2021["Against"].apply(lambda x: x.split(" ")[-1])

games2022["For"] = games2022["For"].apply(lambda x: x.split(" ")[-1])
games2022["Against"] = games2022["Against"].apply(lambda x: x.split(" ")[-1])

games2021["gamename"] = games2021["For"] + " " + games2021["Against"] + " " + "2021"
games2021 = games2021.drop(columns = ["For", "Against"])

games2022["gamename"] = games2022["For"] + " " + games2022["Against"] + " " + "2022"
games2022 = games2022.drop(columns = ["For", "Against"])

for pos in positions:
        games2021[pos + " " + "FOR"] = games2021["gamename"].apply(lambda x: dict2021[x.split(" ")[0]].loc[pos])
for pos in positions:
        games2021[pos + " " + "AGAINST"] = games2021["gamename"].apply(lambda x: dict2021[x.split(" ")[1]].loc[pos])
games2021 = games2021.set_index("gamename")

for pos in positions:
        games2022[pos + " " + "FOR"] = games2022["gamename"].apply(lambda x: dict2022[x.split(" ")[0]].loc[pos])
for pos in positions:
        games2022[pos + " " + "AGAINST"] = games2022["gamename"].apply(lambda x: dict2022[x.split(" ")[1]].loc[pos])
games2022 = games2022.set_index("gamename")
games2022
# Out:
#                          QB FOR  WR1 FOR  WR2 FOR  WR3 FOR  TE FOR  HB FOR  \
# gamename
# Bills Rams 2022              92       95       80       80      83      81
# Saints Falcons 2022          76       90       83       77      72      90
# Browns Panthers 2022         70       90       77       74      80      96
# 49ers Bears 2022             72       89       81       72      97      80
# Steelers Bengals 2022        69       85       78       74      79      85
# ...                         ...      ...      ...      ...     ...     ...
# Browns Steelers 2022         70       90       77       74      80      96
# Chiefs Raiders 2022          95       80       79       76      98      79
# Rams Seahawks 2022           85       98       82       78      83      83
# Cardinals 49ers 2022         84       96       84       80      84      81
# Cowboys Commanders 2022      89       85       83       74      82      88
#
#                          DT FOR  LT FOR  LE FOR  RE FOR  ...  FS AGAINST  \
# gamename                                                 ...
# Bills Rams 2022              75      83      76      92  ...          76
# Saints Falcons 2022          80      72      91      82  ...          73
# Browns Panthers 2022         70      80      82      99  ...          77
# 49ers Bears 2022             75      99      86      94  ...          83
# Steelers Bengals 2022        82      69      75      93  ...          90
# ...                         ...     ...     ...     ...  ...         ...
# Browns Steelers 2022         70      80      82      99  ...          89
# Chiefs Raiders 2022          91      80      74      78  ...          79
# Rams Seahawks 2022           77      71      75      99  ...          84
# Cardinals 49ers 2022         68      75      87      72  ...          87
# Cowboys Commanders 2022      73      95      90      74  ...          78
#
#                          SS AGAINST  CB1 AGAINST  CB2 AGAINST  RT AGAINST  \
# gamename
# Bills Rams 2022                  78           98           78          85
# Saints Falcons 2022              71           89           87          71
# Browns Panthers 2022             82           81           75          83
# 49ers Bears 2022                 73           82           75          58
# Steelers Bengals 2022            82           85           82          87
# ...                             ...          ...          ...         ...
# Browns Steelers 2022             78           79           77          70
# Chiefs Raiders 2022              78           80           80          68
# Rams Seahawks 2022               90           77           74          66
# Cardinals 49ers 2022             87           81           80          79
# Cowboys Commanders 2022          79           89           83          73
#
#                          C AGAINST  LG AGAINST  RG AGAINST  K AGAINST  \
# gamename
# Bills Rams 2022                 71          75          66         79
# Saints Falcons 2022             73          69          84         82
# Browns Panthers 2022            74          67          76         75
# 49ers Bears 2022                65          80          73         77
# Steelers Bengals 2022           75          69          75         83
# ...                            ...         ...         ...        ...
# Browns Steelers 2022            68          73          78         82
# Chiefs Raiders 2022             70          73          71         81
# Rams Seahawks 2022              72          72          78         73
# Cardinals 49ers 2022            56          67          66         80
# Cowboys Commanders 2022         80          82          77         73
#
#                          P AGAINST
# gamename
# Bills Rams 2022                 70
# Saints Falcons 2022             64
# Browns Panthers 2022            82
# 49ers Bears 2022                69
# Steelers Bengals 2022           83
# ...                            ...
# Browns Steelers 2022            69
# Chiefs Raiders 2022             84
# Rams Seahawks 2022              82
# Cardinals 49ers 2022            77
# Cowboys Commanders 2022         82
#
# [272 rows x 46 columns]

# %%
#categorizing data into forecast and modeling
forecast = games2022
modeling = pd.concat([games2020, games2021])
modeling
# Out:
#                          Differential  QB FOR  WR1 FOR  WR2 FOR  WR3 FOR  \
# gamename
# Chiefs Texans 2020                 14      99       98       81       78
# Seahawks Falcons 2020              13      95       89       87       77
# Bills Jets 2020                    10      88       97       87       82
# Raiders Panthers 2020               4      83       80       79       77
# Bears Lions 2020                    4      71       90       75       75
# ...                               ...     ...      ...      ...      ...
# Giants Commanders 2021            -15      70       82       81       77
# Ravens Steelers 2021               -3      90       84       77       76
# Cardinals Seahawks 2021            -8      86       97       81       80
# Rams 49ers 2021                    -3      83       98       86       86
# Chargers Raiders 2021              -3      84       93       85       73
#
#                          TE FOR  HB FOR  DT FOR  LT FOR  LE FOR  ...  \
# gamename                                                         ...
# Chiefs Texans 2020           99      84      92      75      73  ...
# Seahawks Falcons 2020        80      87      78      83      73  ...
# Bills Jets 2020              75      80      80      81      76  ...
# Raiders Panthers 2020        93      90      79      79      77  ...
# Bears Lions 2020             78      82      82      79      88  ...
# ...                         ...     ...     ...     ...     ...  ...
# Giants Commanders 2021       81      86      75      75      80  ...
# Ravens Steelers 2021         93      80      81      92      78  ...
# Cardinals Seahawks 2021      84      83      73      77      90  ...
# Rams 49ers 2021              84      82      83      86      76  ...
# Chargers Raiders 2021        82      86      84      81      72  ...
#
#                          FS AGAINST  SS AGAINST  CB1 AGAINST  CB2 AGAINST  \
# gamename
# Chiefs Texans 2020               83          72           85           78
# Seahawks Falcons 2020            77          80           78           77
# Bills Jets 2020                  75          85           82           74
# Raiders Panthers 2020            80          66           82           76
# Bears Lions 2020                 80          74           80           79
# ...                             ...         ...          ...          ...
# Giants Commanders 2021           76          79           88           84
# Ravens Steelers 2021             89          78           79           77
# Cardinals Seahawks 2021          83          90           78           77
# Rams 49ers 2021                  81          86           83           78
# Chargers Raiders 2021            77          78           90           81
#
#                          RT AGAINST  C AGAINST  LG AGAINST  RG AGAINST  \
# gamename
# Chiefs Texans 2020               70         70          67          68
# Seahawks Falcons 2020            71         87          68          79
# Bills Jets 2020                  69         75          73          69
# Raiders Panthers 2020            85         78          66          68
# Bears Lions 2020                 74         86          71          69
# ...                             ...        ...         ...         ...
# Giants Commanders 2021           71         79          76          87
# Ravens Steelers 2021             70         72          73          78
# Cardinals Seahawks 2021          70         73          72          79
# Rams 49ers 2021                  80         85          80          68
# Chargers Raiders 2021            68         71          89          72
#
#                          K AGAINST  P AGAINST
# gamename
# Chiefs Texans 2020              72         75
# Seahawks Falcons 2020           81         71
# Bills Jets 2020                 67         74
# Raiders Panthers 2020           74         77
# Bears Lions 2020                80         80
# ...                            ...        ...
# Giants Commanders 2021          72         83
# Ravens Steelers 2021            82         72
# Cardinals Seahawks 2021         74         82
# Rams 49ers 2021                 80         78
# Chargers Raiders 2021           80         83
#
# [1056 rows x 47 columns]

# %%
forecast.to_pickle("forecast.pkl")
modeling.to_pickle("modeling.pkl")
